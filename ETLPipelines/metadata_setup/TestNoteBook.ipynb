# %%
# %sql
select * from wx_dbxproject.metadata.tables

# %%
# %sql
update wx_dbxproject.metadata.tables
set source_system='wx_dbxproject', source_schema='02_silver'
where table_id in (6,7,8)

# %%
# %sql
select * from banking.metadata.tables

# %%
# %sql
INSERT INTO wx_dbxproject.metadata.tables VALUES
(6, 'dim_customers', '02_silver', NULL, 'customers', NULL, '02_silver', NUll, NULL, NULL, TRUE, 1, current_timestamp()),
(7, 'dim_restaurants', '02_silver', NUll, 'restaurants', NULL, '02_silver', NULL, NULL, NULL, TRUE, 2, current_timestamp()),
(8, 'dim_menu_items', '02_silver', NULL, 'menu_items', NULL, '02_silver', NULL, NULL, NULL, TRUE, 3, current_timestamp());

# %%
# %sql
select * from banking.metadata.table_parameters

# %%
# %sql
select count(*) from wx_dbxproject.02_silver.historical_orders

# %%
# %sql


select * from wx_dbxproject.01_bronze.orders

# %%
# %sql
---select * from wx_dbxproject.`01_bronze`.orders
---insert into wx_dbxproject.01_bronze.orders
with rn_k as( select order_id, order_timestamp, restaurant_id, customer_id, order_type, items, total_amount, payment_method, order_status , row_number() over (partition by order_id order by insert_timestamp desc) as rn from wx_dbxproject.01_bronze.historical_orders)
insert into wx_dbxproject.01_bronze.orders
select order_id, order_timestamp, restaurant_id, customer_id, order_type, items, total_amount, payment_method, order_status  from rn_k where rn=1

# %%
# %sql
select * from wx_dbxproject.metadata.table_parameters

# %%
# %sql
select count(*) from wx_dbxproject.02_silver.fact_orders
